# %%
from src.settings import get_settings
from pathlib import Path
import json

settings = get_settings()
BASE_DIR = settings.base_dir
dataset_root = BASE_DIR / 'dataset' / 'MIMIC-Ext-MIMIC-CXR-VQA' / 'dataset'

with open(dataset_root / 'train.json', 'r') as f:
    train = json.load(f)
with open(dataset_root / 'valid.json', 'r') as f:
    valid = json.load(f)
with open(dataset_root / 'test.json', 'r') as f:
    test = json.load(f)

# %%
vqa_labels= list(set(vqa_labels))

    
with open('vqa_labels.json', 'w', encoding='utf-8') as f:
    json.dump(vqa_labels, f, ensure_ascii=False, indent=4)
